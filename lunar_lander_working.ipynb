# %%
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.models import Sequential, load_model
import tensorflow as tf
import numpy as np
import gym
import time
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook, tqdm

# %%
class ReplayBuffer(object):
    def __init__(self, max_size, input_shape, n_actions, discrete=False):
        self.mem_size = max_size
        self.input_shape = input_shape
        self.discrete = discrete
        self.state_memory = np.zeros((self.mem_size, input_shape))
        self.new_state_memory = np.zeros((self.mem_size, input_shape))
        dtype = np.int8 if self.discrete else np.float32
        self.action_memory = np.zeros((self.mem_size, n_actions), dtype=dtype)
        self.reward_memory = np.zeros((self.mem_size))
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.mem_cntr = 0
        
    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.reward_memory[index] = reward
        self.terminal_memory[index] = 1-int(done)
        if self.discrete:
            actions = np.zeros(self.action_memory.shape[1])
            actions[action] = 1.0
            self.action_memory[index] = actions
        else:
            self.action_memory[index] = action
        self.mem_cntr += 1
        
    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)
        batch = np.random.choice(max_mem, batch_size)
        
        states = self.state_memory[batch]
        states_ = self.new_state_memory[batch]
        rewards = self.reward_memory[batch]
        actions = self.action_memory[batch]
        terminal = self.terminal_memory[batch]
        
        return states, actions, rewards, states_, terminal
    
def build_dqn(lr, n_actions, input_dims, fc1_dims, fc2_dims):
    model = Sequential([
        Dense(fc1_dims, input_shape=(input_dims, )),
        Activation('relu'),
        Dense(fc2_dims), 
        Activation('relu'),
        Dense(n_actions)
    ])
    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=lr), loss='mse')
    
    return model

class Agent(object):
    def __init__(self, alpha, gamma, n_actions, epsilon, batch_size, input_dims, epsilon_dec=0.996, epsilon_end=0.01, mem_size=100_000, fname='dqn_model.h5'):
        self.action_space = [i for i in range(n_actions)]
        self.n_actions = n_actions
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_dec = epsilon_dec
        self.epsilon_min = epsilon_end
        self.batch_size = batch_size
        self.model_file = fname
        
        self.memory = ReplayBuffer(mem_size, input_dims, n_actions, discrete=True)
        
        self.q_eval = build_dqn(alpha, n_actions, input_dims, 256, 256)
        
    def remember(self, state, action, reward, new_state, done):
        self.memory.store_transition(state, action, reward, new_state, done)
        
    def choose_action(self, state):
        state = state[np.newaxis, :]
        rand = np.random.random()
        if rand < self.epsilon:
            action = np.random.choice(self.action_space)
        else:
            actions = self.q_eval.predict(state)
            action = np.argmax(actions)
            
        return action
    
    def learn(self):
        if self.memory.mem_cntr < self.batch_size:
            return
        state, action, reward, new_state, done = self.memory.sample_buffer(self.batch_size)
        action_values = np.array(self.action_space, dtype=np.int8)
        action_indices = np.dot(action, action_values)
        
        q_eval = self.q_eval.predict(state)
        q_next = self.q_eval.predict(new_state)
        
        q_target = q_eval.copy()
        
        batch_index = np.arange(self.batch_size, dtype=np.int32)
        
        q_target[batch_index, action_indices] = reward + self.gamma*np.max(q_next, axis=1)*done
        
        _ = self.q_eval.fit(state, q_target, verbose=0)
        
        self.epsilon = self.epsilon*self.epsilon_dec if self.epsilon > self.epsilon_min else self.epsilon_min
        
    
    def save_model(self):
        self.q_eval.save(self.model_file)
        
    def load_model(self):
        self.q_eval = load_model(self.model_file)

# %%
MODEL_NAME = 'lunar_256'
GAMMA = 0.99
EPSILON_START = 1.0
EPSILON_END = 0.01
ALPHA = 0.0005
INPUT_DIMS = 8
N_ACTIONS = 4
REPLAY_BUFFER_SIZE = 100_000
BATCH_SIZE = 64
SHOW = False
EPISODES = 500

# %%
if __name__ == '__main__':
    env = gym.make('LunarLander-v2')
    n_games = EPISODES
    agent = Agent(gamma=GAMMA, epsilon=EPSILON_START, alpha=ALPHA, input_dims=INPUT_DIMS, n_actions=N_ACTIONS, mem_size=REPLAY_BUFFER_SIZE, batch_size=BATCH_SIZE, epsilon_end=EPSILON_END)
    
    scores = []
    eps_history = []
    
    for i in tqdm_notebook(range(n_games)):
        done = False
        score = 0
        observation = env.reset()
        while not done:
            action = agent.choose_action(observation)
            observation_, reward, done, info = env.step(action)
            score += reward
            
            if SHOW and not i % 5:
                env.render()
            
            agent.remember(observation, action, reward, observation_, done)
            observation = observation_
            agent.learn()
        
        eps_history.append(agent.epsilon)
        scores.append(score)
        
        avg_score = np.mean(scores[max(0, i-100):(i+1)])

        print('episode ', i, 'score %.2f' % score, 'average score %.2f' % avg_score)
        if i % 10 == 0 and i > 0:
            agent.save_model()
            
        filename = 'lunar_lander'
        x = [i+1 for i in range(n_games)]
    
    env.close()
# Out:
# /var/folders/jk/h_92czjx5jjcf631wf82ht9c0000gn/T/ipykernel_21007/475097242.py:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(n_games)):
#   0%|          | 0/500 [00:00<?, ?it/s]
# 2022-06-24 12:51:04.829379: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-06-24 12:51:04.937221: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# episode  0 score -121.90 average score -121.90
# 2022-06-24 12:51:06.183613: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# episode  1 score -172.70 average score -147.30
# episode  2 score -51.51 average score -115.37
# episode  3 score -92.37 average score -109.62
# episode  4 score -120.65 average score -111.83
# episode  5 score -36.87 average score -99.33
# episode  6 score -222.52 average score -116.93
# episode  7 score -99.93 average score -114.81
# episode  8 score -229.47 average score -127.55
# episode  9 score -121.40 average score -126.93
# episode  10 score -77.13 average score -122.40
# episode  11 score -256.07 average score -133.54
# episode  12 score -200.54 average score -138.70
# episode  13 score -114.38 average score -136.96
# episode  14 score -280.60 average score -146.54
# episode  15 score -5.06 average score -137.69
# episode  16 score -353.36 average score -150.38
# episode  17 score -127.24 average score -149.10
# episode  18 score -100.51 average score -146.54
# episode  19 score -64.10 average score -142.42
# episode  20 score -283.63 average score -149.14
# episode  21 score -38.56 average score -144.11
# episode  22 score -111.69 average score -142.70
# episode  23 score -49.52 average score -138.82
# episode  24 score -51.15 average score -135.32
# episode  25 score -42.77 average score -131.76
# episode  26 score -135.71 average score -131.90
# episode  27 score -47.34 average score -128.88
# episode  28 score -47.66 average score -126.08
# episode  29 score -49.74 average score -123.54
# episode  30 score -401.89 average score -132.52
# episode  31 score -52.77 average score -130.02
# episode  32 score -80.19 average score -128.51
# episode  33 score -115.14 average score -128.12
# episode  34 score -17.26 average score -124.95
# episode  35 score -44.75 average score -122.72
# episode  36 score -67.63 average score -121.24
# episode  37 score -164.94 average score -122.39
# episode  38 score -268.60 average score -126.13
# episode  39 score -112.37 average score -125.79
# episode  40 score -162.85 average score -126.69
# episode  41 score -67.30 average score -125.28
# episode  42 score -226.42 average score -127.63
# episode  43 score -365.88 average score -133.05
# episode  44 score -82.20 average score -131.92
# episode  45 score -190.64 average score -133.19
# episode  46 score -107.64 average score -132.65
# episode  47 score -135.37 average score -132.71
# episode  48 score -336.18 average score -136.86
# episode  49 score -209.20 average score -138.31
# episode  50 score -84.05 average score -137.24
# episode  51 score -31.34 average score -135.21
# episode  52 score -73.00 average score -134.03
# episode  53 score -4.16 average score -131.63
# episode  54 score -46.51 average score -130.08
# episode  55 score -98.92 average score -129.52
# episode  56 score -45.29 average score -128.05
# episode  57 score -45.06 average score -126.61
# episode  58 score -37.75 average score -125.11
# episode  59 score -6.77 average score -123.14
# episode  60 score -30.27 average score -121.61
# episode  61 score -56.37 average score -120.56
# episode  62 score -11.34 average score -118.83
# episode  63 score -87.00 average score -118.33
# episode  64 score -11.78 average score -116.69
# episode  65 score -82.18 average score -116.17
# episode  66 score -44.03 average score -115.09
# episode  67 score -110.07 average score -115.02
# episode  68 score -49.52 average score -114.07
# episode  69 score -54.56 average score -113.22
# episode  70 score -9.54 average score -111.76
# episode  71 score -74.42 average score -111.24
# episode  72 score -172.08 average score -112.07
# episode  73 score -30.59 average score -110.97
# episode  74 score 1.44 average score -109.47
# episode  75 score -46.56 average score -108.64
# episode  76 score -99.05 average score -108.52
# episode  77 score -72.15 average score -108.05
# episode  78 score -22.59 average score -106.97
# episode  79 score -41.61 average score -106.16
# episode  80 score -83.60 average score -105.88
# episode  81 score -299.67 average score -108.24
# episode  82 score -1.59 average score -106.96
# episode  83 score -18.55 average score -105.90
# episode  84 score -111.63 average score -105.97
# episode  85 score -42.86 average score -105.24
# episode  86 score -69.66 average score -104.83
# episode  87 score -97.03 average score -104.74
# episode  88 score -30.66 average score -103.91
# episode  89 score -2.09 average score -102.78
# episode  90 score -16.09 average score -101.82
# episode  91 score -24.59 average score -100.98
# episode  92 score -30.43 average score -100.22
# episode  93 score -53.87 average score -99.73
# episode  94 score -48.10 average score -99.19
# episode  95 score -64.86 average score -98.83
# episode  96 score -64.57 average score -98.48
# episode  97 score -272.92 average score -100.26
# episode  98 score -149.02 average score -100.75
# episode  99 score -89.23 average score -100.63
# episode  100 score -87.48 average score -100.50
# episode  101 score -112.29 average score -100.41
# episode  102 score -85.55 average score -99.55
# episode  103 score -19.61 average score -99.23
# episode  104 score -48.83 average score -98.80
# episode  105 score -16.15 average score -97.76
# episode  106 score -54.74 average score -97.94
# episode  107 score -35.07 average score -96.09
# episode  108 score -30.75 average score -95.40
# episode  109 score -3.08 average score -93.16
# episode  110 score -85.70 average score -92.81
# episode  111 score -58.15 average score -92.62
# episode  112 score -16.63 average score -90.25
# episode  113 score -37.39 average score -88.63
# episode  114 score 18.28 average score -87.32
# episode  115 score -13.86 average score -84.68
# episode  116 score -63.12 average score -85.25
# episode  117 score 8.71 average score -81.67
# episode  118 score -54.03 average score -80.94
# episode  119 score -25.22 average score -80.20
# episode  120 score -61.04 average score -80.17
# episode  121 score -93.61 average score -78.28
# episode  122 score -29.56 average score -78.20
# episode  123 score -22.88 average score -77.32
# episode  124 score -3.76 average score -76.86
# episode  125 score -50.22 average score -76.85
# episode  126 score -41.21 average score -76.84
# episode  127 score -5.32 average score -75.55
# episode  128 score -51.59 average score -75.59
# episode  129 score -70.71 average score -75.82
# episode  130 score -38.56 average score -75.71
# episode  131 score -26.48 average score -71.99
# episode  132 score -42.62 average score -71.89
# episode  133 score -10.66 average score -71.20
# episode  134 score -43.22 average score -70.49
# episode  135 score -16.66 average score -70.48
# episode  136 score -26.46 average score -70.30
# episode  137 score 2.91 average score -69.60
# episode  138 score 18.04 average score -67.79
# episode  139 score -38.06 average score -65.51
# episode  140 score 173.24 average score -62.68
# episode  141 score -36.53 average score -61.43
# episode  142 score -8.21 average score -60.85
# episode  143 score 117.61 average score -57.44
# episode  144 score -33.35 average score -54.15
# episode  145 score -57.04 average score -53.90
# episode  146 score -9.15 average score -52.10
# episode  147 score -1.05 average score -51.05
# episode  148 score -24.72 average score -49.95
# episode  149 score -1.28 average score -46.63
# episode  150 score -76.51 average score -45.32
# episode  151 score 0.98 average score -44.48
# episode  152 score -16.71 average score -44.33
# episode  153 score 6.43 average score -43.55
# episode  154 score 140.23 average score -42.12
# episode  155 score 244.81 average score -39.23
# episode  156 score 234.90 average score -35.93
# episode  157 score 235.38 average score -33.15
# episode  158 score 225.67 average score -30.47
# episode  159 score -185.86 average score -31.94
# episode  160 score -18.76 average score -32.05
# episode  161 score 214.89 average score -29.63
# episode  162 score 211.87 average score -26.97
# episode  163 score 254.15 average score -24.34
# episode  164 score -208.33 average score -25.54
# episode  165 score 220.27 average score -23.25
# episode  166 score 278.66 average score -19.67
# episode  167 score 253.89 average score -16.72
# episode  168 score 247.36 average score -13.19
# episode  169 score 264.60 average score -10.08
# episode  170 score 213.78 average score -7.42
# episode  171 score 266.34 average score -4.69
# episode  172 score 263.39 average score -1.34
# episode  173 score 222.68 average score 2.57
# episode  174 score 275.05 average score 5.59
# episode  175 score 288.75 average score 8.44
# episode  176 score 258.62 average score 11.46
# episode  177 score 282.24 average score 15.23
# episode  178 score 16.23 average score 16.11
# episode  179 score 265.48 average score 18.96
# episode  180 score 257.82 average score 21.93
# episode  181 score 285.12 average score 25.58
# episode  182 score 13.34 average score 28.68
# episode  183 score 267.22 average score 31.34
# episode  184 score -0.40 average score 31.52
# episode  185 score 251.34 average score 35.11
# episode  186 score 263.90 average score 38.15
# episode  187 score -28.26 average score 38.56
# episode  188 score 283.30 average score 42.32
# episode  189 score 252.54 average score 45.13
# episode  190 score 221.75 average score 47.34
# episode  191 score 236.97 average score 49.85
# episode  192 score 25.52 average score 50.35
# episode  193 score -70.77 average score 49.95
# episode  194 score -85.14 average score 49.64
# episode  195 score 261.88 average score 52.71
# episode  196 score 250.77 average score 55.83
# episode  197 score 282.81 average score 59.27
# episode  198 score 260.61 average score 64.55
# episode  199 score 289.28 average score 68.89
# episode  200 score 255.34 average score 72.30
# episode  201 score 264.27 average score 75.79
# episode  202 score 223.96 average score 79.12
# episode  203 score 275.65 average score 82.69
# episode  204 score 183.61 average score 84.70
# episode  205 score 242.63 average score 87.59
# episode  206 score 280.96 average score 90.53
# episode  207 score 278.37 average score 93.83
# episode  208 score -48.02 average score 93.70
# episode  209 score 215.04 average score 96.13
# episode  210 score 195.95 average score 98.11
# episode  211 score -168.25 average score 97.29
# episode  212 score 238.64 average score 100.23
# episode  213 score 268.46 average score 103.05
# episode  214 score 312.44 average score 106.51
# episode  215 score 273.55 average score 109.04
# episode  216 score 152.57 average score 110.69
# episode  217 score 214.50 average score 113.44
# episode  218 score 167.15 average score 115.01
# episode  219 score 266.05 average score 118.17
# episode  220 score 247.68 average score 120.88
# episode  221 score 256.30 average score 124.02
# episode  222 score 133.73 average score 126.27
# episode  223 score -86.71 average score 125.70
# episode  224 score 257.54 average score 128.48
# episode  225 score 249.44 average score 130.99
# episode  226 score 274.37 average score 134.20
# episode  227 score 288.44 average score 137.46
# episode  228 score 276.35 average score 140.25
# episode  229 score 286.95 average score 143.61
# episode  230 score 271.58 average score 146.99
# episode  231 score 193.03 average score 149.29
# episode  232 score 256.77 average score 152.09
# episode  233 score 245.71 average score 154.95
# episode  234 score 247.54 average score 157.50
# episode  235 score 240.56 average score 160.31
# episode  236 score 210.72 average score 162.56
# episode  237 score 191.02 average score 164.72
# episode  238 score 224.20 average score 166.91
# episode  239 score -206.29 average score 164.69
# episode  240 score 280.21 average score 167.84
# episode  241 score 230.98 average score 168.41
# episode  242 score 282.03 average score 171.56
# episode  243 score 243.37 average score 174.05
# episode  244 score 145.64 average score 174.33
# episode  245 score 178.75 average score 176.43
# episode  246 score 263.82 average score 179.61
# episode  247 score 249.57 average score 182.17
# episode  248 score 284.63 average score 185.00
# episode  249 score -290.21 average score 182.37
# episode  250 score 257.66 average score 184.93
# episode  251 score -60.86 average score 185.09
# episode  252 score 228.35 average score 187.34
# episode  253 score 216.74 average score 189.65
# episode  254 score 301.07 average score 192.57
# episode  255 score 253.18 average score 193.69
# episode  256 score 239.12 average score 193.63
# episode  257 score 184.92 average score 193.14
# episode  258 score 264.66 average score 193.43
# episode  259 score 272.13 average score 193.89
# episode  260 score 177.55 average score 197.48
# episode  261 score 256.15 average score 200.21
# episode  262 score 257.67 average score 200.63
# episode  263 score 232.62 average score 200.84
# episode  264 score 308.25 average score 201.37
# episode  265 score 290.92 average score 206.31
# episode  266 score 198.83 average score 206.10
# episode  267 score 308.07 average score 206.39
# episode  268 score 272.18 average score 206.57
# episode  269 score 184.90 average score 205.96
# episode  270 score 289.93 average score 206.21
# episode  271 score 296.33 average score 207.02
# episode  272 score 251.88 average score 206.88
# episode  273 score 242.72 average score 206.68
# episode  274 score 242.60 average score 206.87
# episode  275 score 263.71 average score 206.76
# episode  276 score 282.13 average score 206.70
# episode  277 score 147.53 average score 205.60
# episode  278 score 293.57 average score 205.71
# episode  279 score 228.60 average score 207.81
# episode  280 score 251.85 average score 207.68
# episode  281 score 256.75 average score 207.66
# episode  282 score 280.22 average score 207.62
# episode  283 score 292.58 average score 210.38
# episode  284 score 242.30 average score 210.13
# episode  285 score 250.60 average score 212.62
# episode  286 score 258.91 average score 212.69
# episode  287 score 239.96 average score 212.46
# episode  288 score 243.79 average score 215.15
# episode  289 score 281.20 average score 215.13
# episode  290 score 289.12 average score 215.49
# episode  291 score 232.55 average score 215.60
# episode  292 score 237.10 average score 215.60
# episode  293 score 213.10 average score 217.46
# episode  294 score -56.93 average score 217.59
# episode  295 score 267.70 average score 221.09
# episode  296 score 231.43 average score 220.79
# episode  297 score 238.06 average score 220.66
# episode  298 score 280.31 average score 220.64
# episode  299 score -102.12 average score 217.04
# episode  300 score 13.88 average score 214.32
# episode  301 score 296.37 average score 214.72
# episode  302 score 238.14 average score 214.47
# episode  303 score 243.73 average score 214.66
# episode  304 score 10.00 average score 212.03
# episode  305 score 239.00 average score 212.58
# episode  306 score 260.62 average score 212.76
# episode  307 score 251.35 average score 212.46
# episode  308 score 268.12 average score 212.36
# episode  309 score 249.14 average score 215.30
# episode  310 score 268.58 average score 215.83
# episode  311 score 190.00 average score 215.78
# episode  312 score 293.46 average score 220.35
# episode  313 score 260.98 average score 220.57
# episode  314 score 299.57 average score 220.88
# episode  315 score 289.67 average score 220.65
# episode  316 score 249.25 average score 220.41
# episode  317 score 273.20 average score 221.60
# episode  318 score 237.32 average score 221.83
# episode  319 score 282.37 average score 222.97
# episode  320 score 29.55 average score 220.63
# episode  321 score 292.17 average score 221.07
# episode  322 score 297.89 average score 221.48
# episode  323 score 281.18 average score 222.94
# episode  324 score 204.42 average score 225.82
# episode  325 score 212.26 average score 225.38
# episode  326 score 293.79 average score 225.82
# episode  327 score 263.17 average score 225.70
# episode  328 score 255.66 average score 225.38
# episode  329 score 91.70 average score 223.55
# episode  330 score 271.90 average score 223.40
# episode  331 score 261.67 average score 223.30
# episode  332 score 294.15 average score 224.31
# episode  333 score 265.40 average score 224.39
# episode  334 score 296.07 average score 224.89
# episode  335 score -261.82 average score 219.85
# episode  336 score 261.92 average score 220.06
# episode  337 score 278.77 average score 220.73
# episode  338 score 242.08 average score 221.24
# episode  339 score 273.14 average score 221.72
# episode  340 score 307.35 average score 226.81
# episode  341 score 273.43 average score 226.74
# episode  342 score -298.55 average score 221.50
# episode  343 score 248.56 average score 221.17
# episode  344 score 274.52 average score 221.47
# episode  345 score 275.16 average score 222.76
# episode  346 score -251.89 average score 218.49
# episode  347 score 264.48 average score 218.50
# episode  348 score 259.10 average score 218.59
# episode  349 score 240.97 average score 218.16
# episode  350 score 257.10 average score 223.58
# episode  351 score 234.65 average score 223.35
# episode  352 score 257.22 average score 226.50
# episode  353 score 267.35 average score 226.89
# episode  354 score 260.10 average score 227.32
# episode  355 score 263.67 average score 226.95
# episode  356 score 263.70 average score 227.05
# episode  357 score 262.78 average score 227.29
# episode  358 score 51.05 average score 225.96
# episode  359 score 272.01 average score 226.03
# episode  360 score 278.18 average score 226.09
# episode  361 score 289.95 average score 227.21
# episode  362 score 73.26 average score 225.40
# episode  363 score 273.22 average score 225.55
# episode  364 score 281.98 average score 226.04
# episode  365 score 33.11 average score 223.31
# episode  366 score 254.69 average score 222.95
# episode  367 score 231.73 average score 223.28
# episode  368 score -154.32 average score 218.70
# episode  369 score 313.46 average score 219.11
# episode  370 score -81.57 average score 216.47
# episode  371 score -158.57 average score 212.03
# episode  372 score 263.19 average score 211.70
# episode  373 score 210.06 average score 211.29
# episode  374 score 288.85 average score 211.75
# episode  375 score 285.82 average score 212.17
# episode  376 score 272.61 average score 212.26
# episode  377 score 263.64 average score 212.08
# episode  378 score 271.74 average score 213.31
# episode  379 score 241.81 average score 212.80
# episode  380 score 279.02 average score 213.30
# episode  381 score -236.50 average score 208.46
# episode  382 score 259.83 average score 208.49
# episode  383 score 256.22 average score 208.25
# episode  384 score 303.15 average score 208.36
# episode  385 score 267.78 average score 208.61
# episode  386 score 303.75 average score 209.14
# episode  387 score 256.39 average score 209.11
# episode  388 score 272.90 average score 209.44
# episode  389 score 276.79 average score 209.76
# episode  390 score 267.37 average score 209.63
# episode  391 score 260.17 average score 209.34
# episode  392 score 164.85 average score 208.67
# episode  393 score 265.49 average score 208.95
# episode  394 score 255.33 average score 209.37
# episode  395 score 164.64 average score 211.56
# episode  396 score 167.48 average score 210.57
# episode  397 score 231.19 average score 210.57
# episode  398 score 271.74 average score 210.90
# episode  399 score 274.23 average score 210.84
# episode  400 score 234.10 average score 214.17
# episode  401 score 295.75 average score 216.96
# episode  402 score 252.69 average score 216.53
# episode  403 score 63.47 average score 214.80
# episode  404 score 278.19 average score 215.14
# episode  405 score 231.73 average score 217.34
# episode  406 score 253.59 average score 217.48
# episode  407 score 310.32 average score 217.97
# episode  408 score 297.22 average score 218.43
# episode  409 score 272.19 average score 218.47
# episode  410 score 235.49 average score 218.33
# episode  411 score -23.74 average score 215.44
# episode  412 score 173.95 average score 215.28
# episode  413 score -24.73 average score 212.13
# episode  414 score 255.81 average score 212.08
# episode  415 score 261.45 average score 211.70
# episode  416 score 292.64 average score 211.73
# episode  417 score 17.79 average score 209.44
# episode  418 score 298.75 average score 209.69
# episode  419 score 300.03 average score 210.31
# episode  420 score 282.30 average score 210.31
# episode  421 score 295.33 average score 212.94
# episode  422 score 267.22 average score 212.70
# episode  423 score -47.18 average score 209.28
# episode  424 score 286.38 average score 209.33
# episode  425 score 291.64 average score 210.19
# episode  426 score 40.79 average score 208.50
# episode  427 score 285.02 average score 208.41
# episode  428 score 256.73 average score 208.35
# episode  429 score 265.59 average score 208.44
# episode  430 score 282.14 average score 210.33
# episode  431 score 263.50 average score 210.25
# episode  432 score 52.53 average score 208.18
# episode  433 score 22.10 average score 205.48
# episode  434 score 57.16 average score 203.42
# episode  435 score 251.46 average score 202.98
# episode  436 score 251.35 average score 208.06
# episode  437 score 80.56 average score 206.26
# episode  438 score 250.12 average score 205.98
# episode  439 score 281.91 average score 206.38
# episode  440 score 284.65 average score 206.49
# episode  441 score -2.01 average score 203.43
# episode  442 score 16.01 average score 200.88
# episode  443 score 13.29 average score 203.97
# episode  444 score 59.47 average score 202.09
# episode  445 score 36.55 average score 199.74
# episode  446 score 70.72 average score 197.71
# episode  447 score 278.32 average score 202.96
# episode  448 score 204.70 average score 202.37
# episode  449 score 278.74 average score 202.56
# episode  450 score 260.27 average score 202.76
# episode  451 score 231.94 average score 202.51
# episode  452 score 270.06 average score 202.86
# episode  453 score 282.71 average score 203.11
# episode  454 score 260.95 average score 203.05
# episode  455 score 271.67 average score 203.16
# episode  456 score 283.36 average score 203.36
# episode  457 score 250.78 average score 203.23
# episode  458 score 59.85 average score 201.22
# episode  459 score 275.35 average score 203.44
# episode  460 score 252.97 average score 203.25
# episode  461 score 229.29 average score 202.77
# episode  462 score 280.98 average score 202.68
# episode  463 score 286.72 average score 204.79
# episode  464 score 283.07 average score 204.89
# episode  465 score -88.72 average score 201.22
# episode  466 score 257.73 average score 203.44
# episode  467 score 253.41 average score 203.43
# episode  468 score 288.55 average score 203.99
# episode  469 score 243.42 average score 207.93
# episode  470 score 296.10 average score 207.76
# episode  471 score 297.04 average score 211.51
# episode  472 score 258.49 average score 215.64
# episode  473 score 272.95 average score 215.73
# episode  474 score 213.21 average score 215.76
# episode  475 score 233.59 average score 215.22
# episode  476 score 278.67 average score 215.15
# episode  477 score 270.04 average score 215.12
# episode  478 score 286.46 average score 215.35
# episode  479 score 303.66 average score 215.66
# episode  480 score 266.54 average score 215.91
# episode  481 score 303.21 average score 216.15
# episode  482 score 246.08 average score 220.93
# episode  483 score 230.85 average score 220.64
# episode  484 score 283.21 average score 220.91
# episode  485 score -375.45 average score 214.19
# episode  486 score 201.01 average score 213.53
# episode  487 score -5.74 average score 210.46
# episode  488 score 246.12 average score 210.36
# episode  489 score 246.95 average score 210.10
# episode  490 score 261.24 average score 209.95
# episode  491 score 230.88 average score 209.59
# episode  492 score 275.69 average score 209.74
# episode  493 score 280.61 average score 210.89
# episode  494 score 273.40 average score 210.97
# episode  495 score 232.68 average score 210.74
# episode  496 score 215.19 average score 211.24
# episode  497 score 271.63 average score 212.27
# episode  498 score 53.62 average score 210.52
# episode  499 score 266.55 average score 210.46

# %%
if __name__ == '__main__':    
    done = False
    score = 0
    env = gym.make('LunarLander-v2')
    observation = env.reset()
    smart_agent = Agent(gamma=GAMMA, epsilon=0, alpha=ALPHA, input_dims=INPUT_DIMS, n_actions=N_ACTIONS, mem_size=REPLAY_BUFFER_SIZE, batch_size=BATCH_SIZE)
    smart_agent.load_model()

    while not done:
        action = smart_agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        score += reward
        env.render()  
        smart_agent.remember(observation, action, reward, observation_, done)
        observation = observation_
    env.close()
    print(score)
# Out:
# 2022-06-24 16:35:22.467013: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 235.74135801818903
